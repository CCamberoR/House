# %%
import pandas as pd

df = pd.read_parquet('data_RAG/0000.parquet')

# %%
df
# Out:
#                         id                                              title  \
# 0          pubmed23n0001_0  [Biochemical studies on camomile components/II...
# 1          pubmed23n0001_1  [Demonstration of tumor inhibiting properties ...
# 2          pubmed23n0001_2  Effect of etafenone on total and regional myoc...
# 3          pubmed23n0001_3  Influence of a new virostatic compound on the ...
# 4          pubmed23n0001_4  Pharmacological properties of new neuroleptic ...
# ...                    ...                                                ...
# 256629  pubmed23n0020_5747  Age of menarche in Oaxaca, Mexico, schoolgirls...
# 256630  pubmed23n0020_5748  Anthropometric determination of body volume, b...
# 256631  pubmed23n0020_5749  A Monte Carlo test of weight as a critical fac...
# 256632  pubmed23n0020_5750     Assignment of the DIA1 locus to chromosome 22.
# 256633  pubmed23n0020_5751  The frequency in Japanese of genetic variants ...
#
# ...
